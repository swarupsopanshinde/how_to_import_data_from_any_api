# %%
import pandas as pd
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4NzRhMzJjZGNiMTc0ZWM2Yzc0ZjAyZWQ1ZTk4OTc1MCIsInN1YiI6IjY0YmE5ZDJlNGQyM2RkMDE0NDhkM2E0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.kM07WAbyPK6Rf91xeBGe_HLZHbMMLG--z_dzt08pF2o"
}

response = requests.get(url, headers=headers)

# %%
data = response.json()['results']

# %%
 df = pd.DataFrame(data, columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average'])

df
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3    19404                    Dilwale Dulhania Le Jayenge
# 4      424                               Schindler's List
# 5      129                                  Spirited Away
# 6      389                                   12 Angry Men
# 7   372058                                     Your Name.
# 8   496243                                       Parasite
# 9   569094            Spider-Man: Across the Spider-Verse
# 10     155                                The Dark Knight
# 11     497                                 The Green Mile
# 12     680                                   Pulp Fiction
# 13      13                                   Forrest Gump
# 14     122  The Lord of the Rings: The Return of the King
# ...

# %%
for i in range(1, 1429):
    response = requests.get(url, headers=headers)
    data = response.json()  # Assuming the API returns data in JSON format
    
    # Assuming the API data is a list of dictionaries containing the required fields
    temp_df = pd.DataFrame(data, columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average'])
    
    movie = movie.append(temp_df, ignore_index=True)
print(movie)
# Out:
# C:\Users\Swarup\AppData\Local\Temp\ipykernel_20532\2318591361.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movie = movie.append(temp_df, ignore_index=True)
# C:\Users\Swarup\AppData\Local\Temp\ipykernel_20532\2318591361.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movie = movie.append(temp_df, ignore_index=True)
# C:\Users\Swarup\AppData\Local\Temp\ipykernel_20532\2318591361.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movie = movie.append(temp_df, ignore_index=True)
# C:\Users\Swarup\AppData\Local\Temp\ipykernel_20532\2318591361.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
movie.to_csv('movie.csv')

# %%
movie = pd.DataFrame()

for i in range(1, 1429):
    response = requests.get(url, headers=headers)
    data = response.json()
    temp_df = pd.DataFrame(data, columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average'])
    
    movie = pd.concat([movie, temp_df], ignore_index=True)

# %%
movie
# Out:
# Empty DataFrame
# Columns: [id, title, overview, popularity, release_date, vote_average]
# Index: []

# %%
import pandas as pd
import requests

movie = pd.DataFrame()
url = "https://api.themoviedb.org/3/movie/top_rated"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4NzRhMzJjZGNiMTc0ZWM2Yzc0ZjAyZWQ1ZTk4OTc1MCIsInN1YiI6IjY0YmE5ZDJlNGQyM2RkMDE0NDhkM2E0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.kM07WAbyPK6Rf91xeBGe_HLZHbMMLG--z_dzt08pF2o"
}

for i in range(1, 1429):
    response = requests.get(url, headers=headers)
    data = response.json()
    temp_df = pd.DataFrame(data, columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average'])
    
    movie = pd.concat([movie, temp_df], ignore_index=True)

# %%
movie
# Out:
# Empty DataFrame
# Columns: [id, title, overview, popularity, release_date, vote_average]
# Index: []

# %%
|
